# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.cbf.com.br/futebol-brasileiro/competicoes/campeonato-brasileiro-serie-a/2019')

# %%
len(siglas)
# Out:
# 760

# %%
pattern = []
for index in range(3, 12):
    regex_pattern = ('\w*\s') * index 
    pattern.append(regex_pattern)

# %%
'\w* '*2
# Out:
# '\\w* \\w* '

# %%
'|'.join(pattern)
# Out:
# '\\w*\\s\\w*\\s\\w*\\s|\\w*\\s\\w*\\s\\w*\\s\\w*\\s|\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s|\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s|\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s|\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s|\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s|\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s|\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s\\w*\\s'

# %%
def removing_characters(soup):
    string = str(soup.text).lower() \
    .replace('detalhes do jogo', '') \
    .replace('\n', '') \
    .replace('\r', '') \
    .strip()
    return string

# %%
removing_characters(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-527-0f939d55e8db> in <module>
# ----> 1 removing_characters(i)
#
# <ipython-input-526-30ccf4a9b520> in removing_characters(soup)
#       1 def removing_characters(soup):
# ----> 2     string = str(soup.text).lower() \
#       3     .replace('á', 'a') \
#       4     .replace('ã', 'a') \
#       5     .replace('ê', 'e') \
#
# AttributeError: 'int' object has no attribute 'text'

# %%
time[0]

# %%
len(stadium)
# Out:
# 117

# %%
'alteracao' in 'alteracao      '
# Out:
# True

# %%
siglas = siglas[0:184]

# %%
removing_characters(soup_object[0])
# Out:
# 'sab, 27/04/2019 16:00                            -  jogo: 5'

# %%
np.in

# %%
soup_object.
# Out:
# [<span class="partida-desc text-1 color-lightgray p-b-15 block uppercase text-center">
#                                Sáb, 27/04/2019 16:00
#                              -  Jogo: 5
#                            </span>,
#  <span class="partida-desc text-1 color-lightgray block uppercase text-center">
#                Morumbi - Sao Paulo - SP<br/>
#  <a class="btn btn-xs btn-info m-t-5" href="https://www.cbf.com.br/futebol-brasileiro/competicoes/campeonato-brasileiro-serie-a/2019/5?ref=botao" rel="noopener" target="_blank">Detalhes do jogo</a>
#  </span>,
#  <span class="partida-desc text-1 color-lightgray p-b-15 block uppercase text-center">
#                                Sáb, 27/04/2019 19:00
#                              -  Jogo: 8
#                            </span>,
#  <span class="partida-desc text-1 color-lightgray block uppercase text-center">
#                Arena Condá - Chapeco - SC<br/>
# ...

# %%
date_format = re.compile('\w*,\s(\d{2}\/\d{2}\/\d{4})')
time_format = re.compile('\d{2}:\d{2}')
stadium_format = re.compile('^(.*)-')
city_format = re.compile('-(.*)-')
state_format = re.compile('.*-.*-\s(.*)')

stadium = []
city = []
uf = []
date = []
time = []

for i in range(1, len(soup_object), 2):
    string = removing_characters(soup_object[i])
    
    try:
        stadium.append(stadium_format.findall(string).pop())
        city.append(city_format.findall(string).pop())
        uf.append(state_format.findall(string).pop())
    except:
        stadium.append('A definir')
        city.append('A definir')
        uf.append('A definir')

for i in range(0, (len(soup_object) - 1), 2):
    string = removing_characters(soup_object[i])
    try:
        date.append(date_format.findall(string).pop())
        time.append(time_format.findall(string).pop())
    except:
        date.append('')
        time.append('')

# %%
stadium
# Out:
# ['morumbi - sao paulo ',
#  'arena conda - chapeco ',
#  'independencia - belo horizonte ',
#  'maracana - rio de janeiro ',
#  'arena do gremio - porto alegre ',
#  'arena castelao - fortaleza ',
#  'arena fonte nova - salvador ',
#  'arena da baixada - curitiba ',
#  'allianz parque - sao paulo ',
#  'maracana - rio de janeiro ',
#  'arena corinthians - sao paulo ',
#  'beira-rio - porto alegre ',
#  'rei pelé - maceio ',
#  'ressacada - florianopolis ',
#  'mineirao - belo horizonte ',
#  'sao januario - rio de janeiro ',
#  'arena castelao - fortaleza ',
#  'serra dourada - goiania ',
#  'vila belmiro - santos ',
#  'nilton santos - rio de janeiro ',
#  'allianz parque - sao paulo ',
#  'A definir',
#  'sab, 04/05/2019 21:00                            ',
#  'A definir',
#  'dom, 05/05/2019 11:00                            ',
#  'A definir',
#  'dom, 05/05/2019 16:00                            ',
#  'A definir',
#  'dom, 05/05/2019 16:00                            ',
# ...

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
soup.find_all(attrs={'class':'time pull-left'})[1].find_all(attrs={'class':'time-sigla'})
# Out:
# [<span class="time-sigla">CHA</span>]

# %%
siglas = soup.find_all(attrs={'class':'aside-rodadas swiper-container'})[0]

# %%
siglas = siglas.find_all(attrs={'class':'partida-desc'})

# %%
import re
pattern = re.compile('(\w*,\s\d{2}\/\d{2}\/\d{4}\s\d{2}:\d{2})')
pattern2 = re.compile('')
pattern.findall(str(siglas.find_all(attrs={'class':'partida-desc'})[0].text))
# Out:
# ['Sáb, 27/04/2019 16:00']

# %%
datetime = []
for i in range(380):
    if pattern.findall(str(siglas.find_all(attrs={'class':'partida-desc'})[i].text)) != '':
        datetime.append(pattern.findall(str(siglas.find_all(attrs={'class':'partida-desc'})[i].text)))

# %%
datetime
# Out:
# [['Sáb, 27/04/2019 16:00'],
#  [],
#  ['Sáb, 27/04/2019 19:00'],
#  [],
#  ['Sáb, 27/04/2019 19:00'],
#  [],
#  ['Sáb, 27/04/2019 21:00'],
#  [],
#  ['Dom, 28/04/2019 11:00'],
#  [],
#  ['Dom, 28/04/2019 16:00'],
#  [],
#  ['Dom, 28/04/2019 16:00'],
#  [],
#  ['Dom, 28/04/2019 16:00'],
#  [],
#  ['Dom, 28/04/2019 19:00'],
#  [],
#  ['Dom, 28/04/2019 19:00'],
#  [],
#  ['Qua, 01/05/2019 16:00'],
#  [],
#  ['Qua, 01/05/2019 16:00'],
#  [],
#  ['Qua, 01/05/2019 16:00'],
#  [],
#  ['Qua, 01/05/2019 19:15'],
#  [],
#  ['Qua, 01/05/2019 19:15'],
#  [],
#  ['Qua, 01/05/2019 21:30'],
#  [],
#  ['Qua, 01/05/2019 21:30'],
#  [],
#  ['Qua, 01/05/2019 21:30'],
#  [],
#  ['Qui, 02/05/2019 19:15'],
#  [],
#  ['Qui, 02/05/2019 20:00'],
#  [],
#  ['Sáb, 04/05/2019 19:00'],
#  [],
#  ['Sáb, 04/05/2019 19:00'],
#  [],
#  [],
#  ['Sáb, 04/05/2019 21:00'],
#  [],
#  ['Dom, 05/05/2019 11:00'],
#  [],
#  ['Dom, 05/05/2019 16:00'],
#  [],
#  ['Dom, 05/05/2019 16:00'],
#  [],
#  ['Dom, 05/05/2019 16:00'],
# ...

# %%
siglas.find_all(attrs={'class':'time-sigla'})[index].text
# Out:
# 'BOT'

# %%
# getting the html page from cbf webiste
r = requests.get('https://www.cbf.com.br/futebol-brasileiro/competicoes/campeonato-brasileiro-serie-a/2019')
    
# parsing with beautiful soup
soup = BeautifulSoup(r.content, 'html.parser')


# getting the whole table
tabela = soup.find_all(attrs={'class':'aside-rodadas swiper-container'})

# %%
soup.find(attrs={'class':'aside-rodadas swiper-container'}) \
    .find_all(attrs={'class':'partida-desc text-1 color-lightgray block uppercase text-center'})[2].text
# Out:
# '\r\n              Independência - Belo Horizonte - MG\nDetalhes do jogo\n'

# %%
soup.find(attrs={'class':'aside-rodadas swiper-container'}) \
    .find_all(attrs={'class':'partida-desc text-1 color-lightgray p-b-15 block uppercase text-center'})[0].text
# Out:
# '\r\n                              Sáb, 27/04/2019 16:00\r\n                            -  Jogo: 5 \r\n                          '

# %%
tabela[0].pretiffy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-554-1a189ca7b9bc> in <module>
# ----> 1 tabela[0].pretiffy()
#
# TypeError: 'NoneType' object is not callable

# %%
siglas = siglas.find_all(attrs={'class':'time-sigla'})

# %%
siglas[3].text
# Out:
# 'INT'

# %%
# Out:
# [<span class="time-sigla">SAO</span>,
#  <span class="time-sigla">BOT</span>,
#  <span class="time-sigla">CHA</span>,
#  <span class="time-sigla">INT</span>,
#  <span class="time-sigla">ATL</span>,
#  <span class="time-sigla">AVA</span>,
#  <span class="time-sigla">FLA</span>,
#  <span class="time-sigla">CRU</span>,
#  <span class="time-sigla">GRE</span>,
#  <span class="time-sigla">SAN</span>,
#  <span class="time-sigla">CEA</span>,
#  <span class="time-sigla">CSA</span>,
#  <span class="time-sigla">BAH</span>,
#  <span class="time-sigla">COR</span>,
#  <span class="time-sigla">ATH</span>,
#  <span class="time-sigla">VAS</span>,
#  <span class="time-sigla">PAL</span>,
#  <span class="time-sigla">FOR</span>,
#  <span class="time-sigla">FLU</span>,
#  <span class="time-sigla">GOI</span>,
#  <span class="time-sigla">COR</span>,
#  <span class="time-sigla">CHA</span>,
#  <span class="time-sigla">INT</span>,
#  <span class="time-sigla">FLA</span>,
#  <span class="time-sigla">CSA</span>,
# ...

# %%
def getting
index = 0
teams_home = []
teams_away = []
while index < len(siglas.find_all(attrs={'class':'time-sigla'})):
    if (index == 1) or (index % 2 != 0):
        teams_away.append(sigla(siglas, index))
    elif (index % 2 == 0) or (index == 0):
        teams_home.append(sigla(siglas, index))
    index += 1
# Out:
#   File "<ipython-input-165-6aeb56e9125f>", line 1
#     def getting
#                ^
# SyntaxError: invalid syntax

# %%
def rodadas_brasileiro():
    """
    Cada rodada do brasileiro possui 10 jogos e como os jogos virão ordenados da
    fonte em que eles se encontram:
    (www.cbf.com.br/futebol-brasileiro/competicoes/campeonato-brasileiro-serie-a/2019).
    Criei essa função para retornar uma lista, para identificar cada rodada.
    
    O Campeonato brasileiro tem um total de 380 jogos e esse deve ser o tamanho da lista
    que será o output da função.
    """
    rodadas = []
    for index in range(1, 11):
        index = ((str(index) + ' ') * 10) \
        .strip() \
        .split(' ')
    
    for value in index:
        rodadas.append(value)
        
    assert len(rodadas) == 380
    return rodadas

# %%
def getting_teams()
# Out:
# 380

# %%
len(siglas)
# Out:
# 3
